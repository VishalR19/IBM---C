# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Vishal**
# <br> Data scientist

# %% [markdown]
# *I am interested in data science because & Artificial intelligence because Artificial intelligence has become increasingly important in the world of Fintech. AI can help improve customer service, understand customer behavior and preferences, automate risk management and compliance processes, recommend personalized financial products and aid in fraud prevention. Additionally, AI can be used to gain insights into the data generated by financial transactions and help identify trends and opportunities.*

# %% [markdown]
# ### In the next cell we are adding two numbers and print it using python ###

# %%
a = 1
b = 1
c = a+b
print(a+b)
# Out:
# 2

# %% [markdown]
# Format Text In Jupyter Notebook With Markdown <br>
# **This is a bullet list -** <br> * This is a bullet list 1 <br> * This is a bullet list 2

# %% [markdown]
# **Bold and Italicize -** <br>
# **These are bold words**
# <br>
# *These are italicised words* <br>
# ***These are bold and italicised words***

# %% [markdown]
# **Hyperlink -** <br>

# %% [markdown]
# IBM India website can be found at <a href="https://www.ibm.com/in-en" target="_blank">IBM India</a>
